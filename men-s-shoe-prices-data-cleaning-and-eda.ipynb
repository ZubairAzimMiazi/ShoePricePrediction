# %% [markdown]
# # Men's Shoe Prices
# The goal of this kernel is to complete the **[task](https://www.kaggle.com/sureshmecad/mens-shoe-prices/tasks?taskId=4437)** associated with the dataset. The specific goals include:
# > - What is the average price of each distinct brand listed?
# > - Which brands have the highest prices?
# > - Which ones have the widest distribution of prices?
# > - Is there a typical price distribution (e.g., normal) across brands or within specific brands?
# > - Correlate specific product features with changes in price.
#
# One thing to note before we begin... This dataset includes a lot of information on products that aren't actually shoes! Items such as watches and other accessories seem to have been mistakenly included during the original data gathering process (likely due to mislabeled categories). Fully correcting for this would require a decent amount of manual work / advanced regex and NLP and is outside the scope of this kernel. As a result, please interpret the final outputs with a grain of salt and as not fully reflective of reality beyond this dataset. That being said, the general code and methodologies used within should still be a useful learning experience!
#
# Let's dive in!

# %% [markdown]
# # Imports & Settings

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_theme(context='talk')

# %% [markdown]
# # Data Cleaning / Preprocessing
#
# ## Summary Info
# To start, let's get a general feel for the data we're working with.

# %%
df = pd.read_csv('../input/mens-shoe-prices/train.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19387 entries, 0 to 19386
# Data columns (total 48 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   19387 non-null  object
#  1   asins                2571 non-null   object
#  2   brand                19129 non-null  object
#  3   categories           19387 non-null  object
#  4   colors               11048 non-null  object
#  5   count                0 non-null      float64
#  6   dateadded            19387 non-null  object
#  7   dateupdated          19387 non-null  object
#  8   descriptions         9904 non-null   object
#  9   dimension            2991 non-null   object
#  10  ean                  9999 non-null   float64
#  11  features             13997 non-null  object
#  12  flavors              0 non-null      float64
#  13  imageurls            18342 non-null  object
#  14  isbn                 0 non-null      float64
#  15  keys                 19387 non-null  object
#  16  manufacturer         6699 non-null   object
#  17  manufacturernumber   15147 non-null  object
#  18  merchants            14040 non-null  object
#  19  name                 19387 non-null  object
#  20  prices_amountmin     19377 non-null  object
#  21  prices_amountmax     19387 non-null  object
#  22  prices_availability  197 non-null    object
#  23  prices_color         758 non-null    object
#  24  prices_condition     12621 non-null  object
#  25  prices_count         71 non-null     object
#  26  prices_currency      19311 non-null  object
#  27  prices_dateadded     19372 non-null  object
#  28  prices_dateseen      19362 non-null  object
#  29  prices_flavor        76 non-null     object
#  30  prices_issale        19321 non-null  object
#  31  prices_merchant      13843 non-null  object
#  32  prices_offer         6091 non-null   object
#  33  prices_returnpolicy  1018 non-null   object
#  34  prices_shipping      5753 non-null   object
#  35  prices_size          661 non-null    object
#  36  prices_source        16 non-null     object
#  37  prices_sourceurls    19281 non-null  object
#  38  prices_warranty      108 non-null    object
#  39  quantities           11 non-null     object
#  40  reviews              1664 non-null   object
#  41  sizes                5979 non-null   object
#  42  skus                 8743 non-null   object
#  43  sourceurls           19263 non-null  object
#  44  upc                  10816 non-null  object
#  45  vin                  46 non-null     object
#  46  websiteids           8 non-null      object
#  47  weight               863 non-null    object
# dtypes: float64(4), object(44)
# memory usage: 7.1+ MB
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3170: DtypeWarning: Columns (39,45) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#                      id asins                brand  \
# 0  AVpfHrJ6ilAPnD_xVXOI   NaN                Josmo
# 1  AVpfHrJ6ilAPnD_xVXOI   NaN                Josmo
# 2  AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL
# 3  AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL
# 4  AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL
#
#                                    categories colors  count  \
# 0  Clothing,Shoes,Men's Shoes,All Men's Shoes    NaN    NaN
# 1  Clothing,Shoes,Men's Shoes,All Men's Shoes    NaN    NaN
# 2  All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN    NaN
# 3  All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN    NaN
# 4  All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN    NaN
#
#               dateadded           dateupdated  \
# 0  2016-11-07T00:45:12Z  2016-11-07T00:45:12Z
# 1  2016-11-07T00:45:12Z  2016-11-07T00:45:12Z
# 2  2016-06-14T04:29:57Z  2016-07-09T20:26:48Z
# 3  2016-06-14T04:29:57Z  2016-07-09T20:26:48Z
# 4  2016-06-14T04:29:57Z  2016-07-09T20:26:48Z
#
#                                         descriptions dimension  ...  \
# 0  [{"dateSeen":["2016-11-07T00:45:12Z"],"sourceU...       NaN  ...
# 1  [{"dateSeen":["2016-11-07T00:45:12Z"],"sourceU...       NaN  ...
# 2  [{"dateSeen":["2016-07-09T20:26:48Z"],"sourceU...       NaN  ...
# 3  [{"dateSeen":["2016-07-09T20:26:48Z"],"sourceU...       NaN  ...
# 4  [{"dateSeen":["2016-07-09T20:26:48Z"],"sourceU...       NaN  ...
#
#    prices_warranty quantities  reviews sizes  skus  \
# 0              NaN        NaN      NaN   NaN   NaN
# 1              NaN        NaN      NaN   NaN   NaN
# 2              NaN        NaN      NaN   NaN   NaN
# 3              NaN        NaN      NaN   NaN   NaN
# 4              NaN        NaN      NaN   NaN   NaN
#
#                                           sourceurls           upc  vin  \
# 0  https://www.walmart.com/ip/Josmo-8190-Plain-In...  699302044036  NaN
# 1  https://www.walmart.com/ip/Josmo-8190-Plain-In...  699302044036  NaN
# 2  http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...           NaN  NaN
# 3  http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...           NaN  NaN
# 4  http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...           NaN  NaN
#
#   websiteids weight
# 0        NaN    NaN
# 1        NaN    NaN
# 2        NaN    NaN
# 3        NaN    NaN
# 4        NaN    NaN
#
# [5 rows x 48 columns]

# %%
df.describe()
# Out:
#        count           ean  flavors  isbn
# count    0.0  9.999000e+03      0.0   0.0
# mean     NaN  8.369699e+11      NaN   NaN
# std      NaN  1.021830e+12      NaN   NaN
# min      NaN  1.014667e+07      NaN   NaN
# 25%      NaN  6.759119e+11      NaN   NaN
# 50%      NaN  8.367772e+11      NaN   NaN
# 75%      NaN  8.871196e+11      NaN   NaN
# max      NaN  9.416997e+12      NaN   NaN

# %%
round(df.isna().sum() / df.shape[0], 3)
# Out:
# id                     0.000
# asins                  0.867
# brand                  0.013
# categories             0.000
# colors                 0.430
# count                  1.000
# dateadded              0.000
# dateupdated            0.000
# descriptions           0.489
# dimension              0.846
# ean                    0.484
# features               0.278
# flavors                1.000
# imageurls              0.054
# isbn                   1.000
# keys                   0.000
# manufacturer           0.654
# manufacturernumber     0.219
# merchants              0.276
# name                   0.000
# prices_amountmin       0.001
# prices_amountmax       0.000
# prices_availability    0.990
# prices_color           0.961
# prices_condition       0.349
# prices_count           0.996
# prices_currency        0.004
# prices_dateadded       0.001
# prices_dateseen        0.001
# prices_flavor          0.996
# prices_issale          0.003
# prices_merchant        0.286
# prices_offer           0.686
# prices_returnpolicy    0.947
# prices_shipping        0.703
# prices_size            0.966
# prices_source          0.999
# prices_sourceurls      0.005
# prices_warranty        0.994
# quantities             0.999
# reviews                0.914
# sizes                  0.692
# skus                   0.549
# sourceurls             0.006
# upc                    0.442
# vin                    0.998
# websiteids             1.000
# weight                 0.955
# dtype: float64

# %% [markdown]
# ## Dropping Columns
# The data is fairly messy as it currently stands. There are lots of missing values (some columns are even entirely missing) and there are various data types that need corrected. Given the limited number of questions being answered for this task, a good chunk of the available data is irrelevant. Right off the bat, let's eliminate any columns that are missing 80% or more of their values. This will help reduce the size of the data we're working with and make further cleaning processes a bit easier.

# %%
cols_to_drop = [col for col in df.columns if df[col].isna().sum() >= 0.8*df.shape[0]]
cols_to_drop
# Out:
# ['asins',
#  'count',
#  'dimension',
#  'flavors',
#  'isbn',
#  'prices_availability',
#  'prices_color',
#  'prices_count',
#  'prices_flavor',
#  'prices_returnpolicy',
#  'prices_size',
#  'prices_source',
#  'prices_warranty',
#  'quantities',
#  'reviews',
#  'vin',
#  'websiteids',
#  'weight']

# %%
df.drop(columns=cols_to_drop, inplace=True)
df.columns
# Out:
# Index(['id', 'brand', 'categories', 'colors', 'dateadded', 'dateupdated',
#        'descriptions', 'ean', 'features', 'imageurls', 'keys', 'manufacturer',
#        'manufacturernumber', 'merchants', 'name', 'prices_amountmin',
#        'prices_amountmax', 'prices_condition', 'prices_currency',
#        'prices_dateadded', 'prices_dateseen', 'prices_issale',
#        'prices_merchant', 'prices_offer', 'prices_shipping',
#        'prices_sourceurls', 'sizes', 'skus', 'sourceurls', 'upc'],
#       dtype='object')

# %% [markdown]
# Starting to get somewhere, but there's still more columns to drop:

# %%
df.drop(columns=['id', 'dateadded', 'dateupdated', 'descriptions', 'ean', 
                 'features', 'imageurls', 'keys', 'manufacturer',
                 'manufacturernumber', 'merchants', 'prices_condition',
                 'prices_dateadded', 'prices_dateseen', 'prices_issale',
                 'prices_merchant', 'prices_offer', 'prices_shipping',
                 'prices_sourceurls', 'sizes', 'skus', 'sourceurls', 'upc'],
       inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19387 entries, 0 to 19386
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand             19129 non-null  object
#  1   categories        19387 non-null  object
#  2   colors            11048 non-null  object
#  3   name              19387 non-null  object
#  4   prices_amountmin  19377 non-null  object
#  5   prices_amountmax  19387 non-null  object
#  6   prices_currency   19311 non-null  object
# dtypes: object(7)
# memory usage: 1.0+ MB

# %% [markdown]
# ## Adjusting Data Types

# %% [markdown]
# Some finishing touches by adjusting the data types:

# %%
df.prices_amountmin = pd.to_numeric(df.prices_amountmin, errors='coerce', downcast='float')
df.prices_amountmax = pd.to_numeric(df.prices_amountmax, errors='coerce', downcast='float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19387 entries, 0 to 19386
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand             19129 non-null  object
#  1   categories        19387 non-null  object
#  2   colors            11048 non-null  object
#  3   name              19387 non-null  object
#  4   prices_amountmin  19294 non-null  float32
#  5   prices_amountmax  19350 non-null  float32
#  6   prices_currency   19311 non-null  object
# dtypes: float32(2), object(5)
# memory usage: 908.9+ KB

# %%
df.head()
# Out:
#                  brand                                  categories colors  \
# 0                Josmo  Clothing,Shoes,Men's Shoes,All Men's Shoes    NaN
# 1                Josmo  Clothing,Shoes,Men's Shoes,All Men's Shoes    NaN
# 2  SERVUS BY HONEYWELL  All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN
# 3  SERVUS BY HONEYWELL  All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN
# 4  SERVUS BY HONEYWELL  All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN
#
#                                                 name  prices_amountmin  \
# 0  Josmo 8190 Plain Infant Walking Shoes, Navy - ...         39.889999
# 1  Josmo 8190 Plain Infant Walking Shoes, Navy - ...         51.990002
# 2         Servus By Honeywell Shoe Studs Zsr101blmlg         40.020000
# 3         Servus By Honeywell Shoe Studs Zsr101blmlg         50.310001
# 4         Servus By Honeywell Shoe Studs Zsr101blmlg         46.259998
#
#    prices_amountmax prices_currency
# 0         39.889999             USD
# 1         51.990002             USD
# 2         40.020000             USD
# 3         50.310001             USD
# 4         46.259998             USD

# %% [markdown]
# Much better!
#
# ## Cleaning Final Dataframe
# ### Prices
# The two columns for price (`prices_amountmin` and `prices_amountmax`) caught my eye since the first five rows in the dataframe have the same value for both. To investigate this further, let's check what percentage of the rows have the same value in both columns.

# %%
sum(df.prices_amountmin == df.prices_amountmax) / df.shape[0]
# Out:
# 0.9614690256357353

# %% [markdown]
# Over 96%! As a result, I'm okay with combining the two columns into a single column called `price` by taking the average.

# %%
df['price'] = np.mean([df.prices_amountmin, df.prices_amountmax], axis=0)
df_cleaned = df.drop(columns=['prices_amountmin', 'prices_amountmax'])
df_cleaned.head()
# Out:
#                  brand                                  categories colors  \
# 0                Josmo  Clothing,Shoes,Men's Shoes,All Men's Shoes    NaN
# 1                Josmo  Clothing,Shoes,Men's Shoes,All Men's Shoes    NaN
# 2  SERVUS BY HONEYWELL  All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN
# 3  SERVUS BY HONEYWELL  All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN
# 4  SERVUS BY HONEYWELL  All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN
#
#                                                 name prices_currency  \
# 0  Josmo 8190 Plain Infant Walking Shoes, Navy - ...             USD
# 1  Josmo 8190 Plain Infant Walking Shoes, Navy - ...             USD
# 2         Servus By Honeywell Shoe Studs Zsr101blmlg             USD
# 3         Servus By Honeywell Shoe Studs Zsr101blmlg             USD
# 4         Servus By Honeywell Shoe Studs Zsr101blmlg             USD
#
#        price
# 0  39.889999
# 1  51.990002
# 2  40.020000
# 3  50.310001
# 4  46.259998

# %% [markdown]
# Next, let's check the value counts for the `prices_currency` column.

# %%
df_cleaned.prices_currency.value_counts()
# Out:
# USD                                                   18524
# AUD                                                     338
# CAD                                                     303
# EUR                                                     107
# GBP                                                      22
# UnbeatableSale.com, Inc. - Walmart.com                    3
# new                                                       3
# PalmBeach Jewelry - Walmart.com                           3
# New with box                                              3
# Wholesale Costume and Party Supplies - Walmart.com        2
# Shoes.com                                                 1
# SHOEBACCA LTD. - Walmart.com                              1
# New without tags                                          1
# Name: prices_currency, dtype: int64

# %% [markdown]
# It appears that some data was incorrectly placed in the `prices_currency` column in the original dataset. The overwhelming majority is priced in USD though. We could either work on converting the other currencies to USD for accurate comparisons, or simply drop those rows. For the sake of simplicity in this kernel, let's drop the rows.

# %%
df_cleaned = df_cleaned[df_cleaned.prices_currency == 'USD']
df_cleaned.prices_currency.value_counts()
# Out:
# USD    18524
# Name: prices_currency, dtype: int64

# %% [markdown]
# ### Missing Values

# %%
df_cleaned.isna().sum()
# Out:
# brand                17
# categories            0
# colors             7984
# name                  0
# prices_currency       0
# price                 0
# dtype: int64

# %% [markdown]
# The missing values in the `color` column are fine for now but the 17 missing values for the `brand` column need handled.

# %%
df_cleaned.dropna(axis=0, subset=['brand'], inplace=True)
df_cleaned.isna().sum()
# Out:
# brand                 0
# categories            0
# colors             7981
# name                  0
# prices_currency       0
# price                 0
# dtype: int64

# %% [markdown]
# ### Standardizing Brands
# Finally, let's change all of the brand names to lowercase. This is to help prevent any variations in capitalization from being classified as different brands. While a more serious method of cleaning the brand names would need to be employed in any sort of production code, this will suffice for now.

# %%
df_cleaned.brand = df_cleaned.brand.apply(lambda x: x.lower(), convert_dtype=False)
df_cleaned.brand.head()
# Out:
# 0                  josmo
# 1                  josmo
# 2    servus by honeywell
# 3    servus by honeywell
# 4    servus by honeywell
# Name: brand, dtype: object

# %% [markdown]
# # Answering the Questions
# ## What is the average price of each distinct brand listed?
# To begin answering this questions, let's first take a look at how many unique brands are in the data.

# %%
df_cleaned.brand.nunique()
# Out:
# 1735

# %% [markdown]
# Wow! That's way too many to effectively visualize. Let's limit the brands we look at to only those with more than 50 rows of data. This will help eliminate random, unheard of brands with only a couple entries as well as entries which aren't actually

# %%
brands_above_50 = df_cleaned.brand.value_counts()[df_cleaned.brand.value_counts() > 50]
brands_above_50
# Out:
# nike                           1778
# ralph lauren                    699
# puma                            610
# vans                            386
# new balance                     371
# reebok                          277
# adidas                          258
# jordan                          200
# superior glove works            182
# fossa apparel                   174
# fuse lenses                     174
# skechers                        165
# converse                        153
# dickies                         144
# unbranded                       134
# unique bargains                 127
# berne apparel                   126
# crocs                           120
# toms                            115
# asics                           114
# kinco                           110
# national safety apparel inc     107
# under armour                    105
# gameday boots                   103
# stacy adams                      98
# scully                           96
# georgia boot                     94
# polo ralph lauren                92
# carhartt                         90
# justin boots                     90
# carrera                          86
# alpine swiss                     85
# portwest                         84
# propet                           84
# azzuro                           83
# kenneth cole ny                  79
# muk luks                         77
# academie                         68
# fizik                            66
# onguard                          64
# casio                            61
# dr. martens                      59
# dockers                          59
# bgood                            59
# invicta                          57
# ray-ban                          57
# dvs                              56
# cole haan                        55
# rocky                            54
# caterpillar                      54
# maui jim                         53
# fila                             53
# Name: brand, dtype: int64

# %%
df_brands = df_cleaned[df_cleaned.brand.isin(brands_above_50.index)].groupby('brand').mean()
df_brands.sort_values('price', ascending=False, inplace=True)
df_brands
# Out:
#                                   price
# brand
# ralph lauren                 509.997437
# invicta                      414.075256
# casio                        384.682953
# fizik                        296.242737
# gameday boots                235.530197
# scully                       230.631042
# national safety apparel inc  209.457199
# maui jim                     184.454620
# justin boots                 172.847672
# georgia boot                 163.283829
# ray-ban                      160.380173
# superior glove works         138.317200
# rocky                        133.877228
# kinco                        130.445633
# cole haan                    126.020729
# bgood                        123.624069
# jordan                       117.739273
# carrera                      112.396278
# caterpillar                  109.932961
# adidas                       109.491005
# kenneth cole ny              106.038353
# dr. martens                  104.921783
# nike                          97.865257
# asics                         79.071625
# fossa apparel                 77.596207
# under armour                  77.464287
# berne apparel                 75.783890
# new balance                   75.556404
# puma                          72.025650
# propet                        71.193092
# polo ralph lauren             69.247826
# skechers                      67.711365
# alpine swiss                  62.794941
# stacy adams                   61.915001
# reebok                        60.694366
# toms                          51.648304
# converse                      50.901928
# academie                      50.703236
# fuse lenses                   50.061550
# vans                          50.042656
# dvs                           46.865002
# fila                          46.403584
# unbranded                     46.228806
# azzuro                        45.579639
# portwest                      42.606667
# carhartt                      40.765110
# onguard                       38.774376
# dickies                       38.732361
# crocs                         36.584751
# dockers                       33.086441
# muk luks                      30.709480
# unique bargains               14.538110

# %%
fig = plt.figure(figsize=(8, 16))
sns.barplot(data=df_brands, x='price', y=df_brands.index, palette='crest')
plt.title('Average Price by Brand')
plt.xlabel('Price')
plt.ylabel('Brand')
plt.annotate(text='Note: only brands with more than 50 observations are included.',
             xy=(60, 50),
             fontsize=12);

# %% [markdown]
# ## Which brands have the highest prices?

# %%
df_max_prices = df_cleaned[df_cleaned.brand.isin(brands_above_50.index)].sort_values('price', ascending=False)
df_max_prices = df_max_prices.drop_duplicates('brand')
df_max_prices[['brand', 'name', 'price']]
# Out:
#                              brand  \
# 1452                        adidas
# 15719                 ralph lauren
# 17345  national safety apparel inc
# 13901                      invicta
# 4388          superior glove works
# 554                          casio
# 11249                         nike
# 4020                     unbranded
# 6977                          puma
# 17131                       jordan
# 9452             polo ralph lauren
# 13057                       scully
# 13805                        fizik
# 11369                  new balance
# 8094                      maui jim
# 12331                gameday boots
# 1322                  justin boots
# 19225                 georgia boot
# 16783                      ray-ban
# 8939                  alpine swiss
# 5965                     cole haan
# 9821                         rocky
# 18320              kenneth cole ny
# 18877                        kinco
# 7245                       carrera
# 1100                  under armour
# 14644                        bgood
# 12084                     carhartt
# 6025                   caterpillar
# 246                    dr. martens
# 15704                        asics
# 17563                      dickies
# 763                       skechers
# 13657                      onguard
# 6094                   fuse lenses
# 8122                        reebok
# 670                            dvs
# 6693                          toms
# 19216                       propet
# 14965                berne apparel
# 573                  fossa apparel
# 7597                   stacy adams
# 3305                      converse
# 11907                         vans
# 16469                     academie
# 18921                       azzuro
# 4062                      muk luks
# 10840                      dockers
# 10290                         fila
# 1676                         crocs
# 5345               unique bargains
# 6833                      portwest
#
#                                                     name        price
# 1452   Yeezy Boost 350 Turtle Doves Kanye West 2015 P...  2799.949951
# 15719                        Crocodile Barnet Espadrille  2100.000000
# 17345  National Safety Apparel Inc National Safety Ap...  2083.030029
# 13901  Invicta Men's 6105 Venom Reserve Chronograph G...  1995.000000
# 4388   Superior Glove Works Superior Spgrk Contender ...  1647.310059
# 554    Casio G-shock Mt-g Tough Solar  Mens Watch Mtg...  1400.000000
# 11249  Nike Air Jordan Xii 12 Rare Wings Men's Shoes ...  1225.000000
# 4020   "Men's Black Faux Leather Business Briefcase M...  1134.989990
# 6977   Jersey Chivas 110 A��os Conmemorativa 1906 Pie...  1100.000000
# 17131  "Jordan Mens Air Jordan 11 Retro Prem "grey Su...   749.000000
# 9452   Ralph Lauren Polo 100% Wool Black Fairbanks Tu...   499.989990
# 13057  Scully 907-12-s Mens Leather Wear Jacket44 Bro...   440.359985
# 13805             Fizik Men's R1 Uomo Road Cycling Shoes   400.000000
# 11369  "New Balance Mens Concepts M 997 Cpt "rose" Ro...   369.000000
# 8094   New Genuine Maui Jim Wassup Ht12302mr Mens Sun...   318.000000
# 12331       Gameday Boots Mens Leather Navy Cowboy Boots   310.989990
# 1322   Justin Boots Work Boots Mens Composition Toe H...   294.000000
# 19225  Georgia Boot G8315 10.5 M Work Boots,stl,met G...   283.239990
# 16783  New Ray Ban Rb3513jm 164t3 Aviator Flat Metal ...   267.850006
# 8939   Alpine Swiss Alpineswiss Leather Briefcase Lap...   260.000000
# 5965   Cole Haan Cambridge Men's Derby Oxford Dress S...   258.000000
# 9821   Rocky Tactical Boot Mens S2v Composite Toe Mil...   239.990005
# 18320  Kenneth Cole Ny Park The Car   Round Toe Leath...   218.000000
# 18877  Kinco 2060 Pro Winterpro Lined Winter Syntheti...   215.929993
# 7245   Carrera Carrera 6000/tx (fty/zp) 51-23-145 Ori...   215.000000
# 1100   Under Armour Haw 2.0 Boot Realtree Xtra 800g 1...   211.949997
# 14644  Bgood Winter Mens Warm Fleece Jacket Coat Wool...   209.610001
# 12084  Carhartt 8 Force W Composite Toe Leather Work ...   188.000000
# 6025         Caterpillar Men Manifold 6' Steel Toe Boots   185.000000
# 246                          Dr. Martens Men's Jace Boot   185.000000
# 15704     Asics Gel Quantum 360 Running Men's Shoes Size   170.000000
# 17563  Men's 3x-large Flame Resistant Long Sleeve Cov...   170.000000
# 763    Skechers 54503 Choc Men's Go Golf Elite 2 - Lx...   155.000000
# 13657  Onguard Size 14 Steel Toe Knee Boots, Men's, G...   154.059998
# 6094   Fuse Lenses For Ray-ban Rj9053s (kids) Photoch...   146.979996
# 8122   Reebok Court Victory Pump Grizzly Brown Men's ...   139.949997
# 670      Dvs Yodeler Men  Round Toe Leather  Chukka Boot   130.000000
# 6693              Toms Bota   Round Toe Canvas  Sneakers   129.000000
# 19216   Propet Mack - Men's Rejuve Boots - Gunsmoke/gold   119.949997
# 14965  Berne Apparel Js204hkyr440 Sattelhorn Coat44 H...   116.830002
# 573    Fossa Apparel 5580-charcoal-5xl 5x-large Men's...   110.779999
# 7597   Stacy Adams Bingham Men  Cap Toe Leather Tan O...   110.000000
# 3305       Converse Chuck Taylor Street Hiker Shoes Size    95.000000
# 11907       Vans Alomar    Round Toe Synthetic  Sneakers    90.000000
# 16469  Academie Tuffex-cw-v 10-3 Eyelet Lace School S...    89.919998
# 18921  Azzuro Men Long Sleeve Stretch Hem Zipper Deco...    85.989998
# 4062                           Muk Luks Men's Ross Shoes    85.000000
# 10840  Dockers Men's Dockers, Sansome Lace Up Dress Shoe    80.000000
# 10290                Fila Men's Shifter Black Ankle Boot    75.000000
# 1676   Crocs Men's Kinsale Slip-on Ankle-high Canvas ...    74.989998
# 5345   G Antini Unisex Check Pattern Canvas Shoe Blue...    71.989998
# 6833   Portwest Fw31 Regular Steelite Mid Cut Nubuck ...    67.300003

# %%
fig = plt.figure(figsize=(8, 16))
sns.barplot(data=df_max_prices, x='price', y='brand', palette='crest')
plt.title('Max Price by Brand')
plt.xlabel('Price')
plt.ylabel('Brand');
plt.annotate(text='Note: only brands with more than 50 observations are included.',
             xy=(300, 50),
             fontsize=12);

# %% [markdown]
# ## Which ones have the widest distribution of prices?

# %%
df_medians = df_cleaned[df_cleaned.brand.isin(brands_above_50.index)]
df_medians = df_medians.groupby('brand').median()
df_medians = df_medians.sort_values('price', ascending=False)
df_medians.head()
# Out:
#                     price
# brand
# ralph lauren   425.000000
# casio          383.579987
# fizik          290.622498
# gameday boots  259.989990
# invicta        204.990005

# %% [markdown]
# The answer to this question is up for debate depending on the interpretation of the question. "Widest distribution" could be defined in a number of ways including:
# - Standard deviation (nominal or as a percentage)
# - The interquratile range (IQR)
# - Difference between maximum and minimum values
#
# Most of this information can be captured by utilizing boxplots. The boxplots could be ordered in a number of ways, but using the median tends to yield a fairly orderly result.

# %%
fig = plt.figure(figsize=(8, 16))
sns.boxplot(data=df_cleaned[df_cleaned.brand.isin(brands_above_50.index)],
            x='price',
            y='brand',
            order=df_medians.index,
            palette='crest',
            orient='h')
plt.title('Boxplots for Price by Brand')
plt.xlabel('Price')
plt.ylabel('Brand')
plt.annotate(text='Note: only brands with more than 50 observations are included.',
             xy=(300, 50),
             fontsize=12);

# %% [markdown]
# ## Is there a typical price distribution (e.g., normal) across brands or within specific brands?

# %%
df_all_dist = df_cleaned[df_cleaned.brand.isin(brands_above_50.index)]
fig = plt.figure(figsize=(8, 6))
sns.kdeplot(df_all_dist['price'], clip=(0, None))
plt.title('Distribution of Prices')
plt.xlabel('Price');
plt.annotate(text='Note: only brands with more than 50 observations are included.',
             xy=(300, 0.0065),
             fontsize=12);

# %% [markdown]
# The distribution of all prices for brands with more than 50 observations is heavily skewed to the right. Let's takes a look at what happens when we apply a log transformation:

# %%
fig = plt.figure(figsize=(8, 6))
sns.kdeplot(df_all_dist['price'], clip=(0, None), log_scale=True)
plt.title('Distribution of Prices')
plt.xlabel('Log Price');

# %% [markdown]
# So it appears that the prices are log-normally distributed. We can check the distribution of an individual brand with more than 50 observations by creating a simple function.

# %%
def plot_brand_distribution(brand, log=False):
    '''
    Description: Takes a brand name and boolean value for log and plots a KDE plot for the distribution
    of that specific brand's prices (log prices if log == True).
    
    Inputs:
    - brand : str
         The name of the brand to visualize. Must have more than 50 observations in the original data set.
         Case insensitive as it will automatically be lowercased.
    
    - log : boolean, default = False
         Determines whether a log transformation should be applied to the prices.
    '''
    fig = plt.figure(figsize=(8, 6))
    sns.kdeplot(df_all_dist[df_all_dist.brand == brand.lower()]['price'], clip=(0, None), log_scale=log)
    plt.title(f'Distribution of {brand.title()}\'s Prices')
    plt.xlabel('Log Price' if log else 'Price')
    plt.show();

# %%
plot_brand_distribution('nike', False)

# %%
plot_brand_distribution('Adidas', True)

# %% [markdown]
# # Conclusion
# That's it for this kernel! Correlating prices with specific product attributes may be added in a future update, but would require significantly more data cleaning and preprocessing.
#
# **If you liked this notebook or have any feedback, please let me know in the comments. I'm always looking to improve!**
